# %% [markdown]
# # La roue des émotions

# %%
import pandas as pd
import string
import numpy as np

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import ngrams

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import copy
from collections import Counter

from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer, HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.svm import LinearSVC
from sklearn import svm
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix

import joblib
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import nltk
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\straw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\straw\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\straw\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv(r'C:\Users\straw\Desktop\AIS\ProjectPool 2\Roue-des-emotions\Data\emotions_final.csv', sep=',')
df
# Out:
#                                                     Text  Emotion
# 0                                i didnt feel humiliated  sadness
# 1      i can go from feeling so hopeless to so damned...  sadness
# 2       im grabbing a minute to post i feel greedy wrong    anger
# 3      i am ever feeling nostalgic about the fireplac...     love
# 4                                   i am feeling grouchy    anger
# ...                                                  ...      ...
# 21454               Melissa stared at her friend in dism     fear
# 21455  Successive state elections have seen the gover...     fear
# 21456               Vincent was irritated but not dismay     fear
# 21457  Kendall-Hume turned back to face the dismayed ...     fear
# 21458                    I am dismayed , but not surpris     fear
#
# [21459 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21459 entries, 0 to 21458
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Text     21459 non-null  object
#  1   Emotion  21459 non-null  object
# dtypes: object(2)
# memory usage: 335.4+ KB

# %% [markdown]
# ### Classes du dataset

# %%
S = df['Emotion'].value_counts()
S
# Out:
# joy         7029
# sadness     6265
# anger       2993
# fear        2652
# love        1641
# surprise     879
# Name: Emotion, dtype: int64

# %% [markdown]
# #### Countplot

# %%
sns.countplot(x='Emotion', data=df, palette='hls')
plt.title('Distribution des émotions dans le dataset')
plt.show()

# %% [markdown]
# #### Piechart

# %%
fig = px.pie(S, values=S.values, names=S.index, title='Distribution des émotions dans le dataset')
fig.show()
# Out:
# <div>                            <div id="cf71a83d-fea3-4fca-990c-7d9b005a0c8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf71a83d-fea3-4fca-990c-7d9b005a0c8e")) {                    Plotly.newPlot(                        "cf71a83d-fea3-4fca-990c-7d9b005a0c8e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["joy","sadness","anger","fear","love","surprise"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[7029,6265,2993,2652,1641,879]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":
# ...

# %% [markdown]
# ### Normalisation

# %%
lowers = []
for i in range(0, df.shape[0]):
    lowers.append(df['Text'][i].lower())

# %%
df['Text'] = lowers
df['Text']
# Out:
# 0                                  i didnt feel humiliated
# 1        i can go from feeling so hopeless to so damned...
# 2         im grabbing a minute to post i feel greedy wrong
# 3        i am ever feeling nostalgic about the fireplac...
# 4                                     i am feeling grouchy
#                                ...
# 21454                 melissa stared at her friend in dism
# 21455    successive state elections have seen the gover...
# 21456                 vincent was irritated but not dismay
# 21457    kendall-hume turned back to face the dismayed ...
# 21458                      i am dismayed , but not surpris
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Tokénization

# %%
df['Text'] = df['Text'].apply(word_tokenize)
df['Text']
# Out:
# 0                             [i, didnt, feel, humiliated]
# 1        [i, can, go, from, feeling, so, hopeless, to, ...
# 2        [im, grabbing, a, minute, to, post, i, feel, g...
# 3        [i, am, ever, feeling, nostalgic, about, the, ...
# 4                                [i, am, feeling, grouchy]
#                                ...
# 21454         [melissa, stared, at, her, friend, in, dism]
# 21455    [successive, state, elections, have, seen, the...
# 21456          [vincent, was, irritated, but, not, dismay]
# 21457    [kendall-hume, turned, back, to, face, the, di...
# 21458              [i, am, dismayed, ,, but, not, surpris]
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Suppression des stop words et de la ponctuation

# %%
stopW = stopwords.words('english')
stopW.extend(list(string.punctuation))

# %%
def remove_stopwords(sent):
    tokens_without_stopW = [word for word in sent if word not in stopW]
    return tokens_without_stopW

# %%
df['Text'] = df['Text'].apply(lambda sent: remove_stopwords(sent))

# %% [markdown]
# ### Stemming et Lemmatization

# %%
wnl = WordNetLemmatizer()

# %%
def lemmatize(sent, join=True):
    tokens = [wnl.lemmatize(wnl.lemmatize(wnl.lemmatize(w,'v'),'n'),'a') for w in sent]
    if join:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_explo = copy.deepcopy(df)

# %%
df['Text'] = df['Text'].apply(lambda sent: lemmatize(sent))

# %%
df_explo['Text'] = df_explo['Text'].apply(lambda sent: lemmatize(sent, join=False))

# %%
df_explo['Text']
# Out:
# 0                                 [didnt, feel, humiliate]
# 1        [go, feel, hopeless, damn, hopeful, around, so...
# 2            [im, grab, minute, post, feel, greedy, wrong]
# 3        [ever, feel, nostalgic, fireplace, know, still...
# 4                                          [feel, grouchy]
#                                ...
# 21454                        [melissa, star, friend, dism]
# 21455    [successive, state, election, see, govern, par...
# 21456                          [vincent, irritate, dismay]
# 21457       [kendall-hume, turn, back, face, dismay, coup]
# 21458                                    [dismay, surpris]
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Exploration des données

# %%
df_explo['Length'] = df_explo['Text'].apply(len)
df_explo
# Out:
#                                                     Text  Emotion  Length
# 0                               [didnt, feel, humiliate]  sadness       3
# 1      [go, feel, hopeless, damn, hopeful, around, so...  sadness       9
# 2          [im, grab, minute, post, feel, greedy, wrong]    anger       7
# 3      [ever, feel, nostalgic, fireplace, know, still...     love       7
# 4                                        [feel, grouchy]    anger       2
# ...                                                  ...      ...     ...
# 21454                      [melissa, star, friend, dism]     fear       4
# 21455  [successive, state, election, see, govern, par...     fear       9
# 21456                        [vincent, irritate, dismay]     fear       3
# 21457     [kendall-hume, turn, back, face, dismay, coup]     fear       6
# 21458                                  [dismay, surpris]     fear       2
#
# [21459 rows x 3 columns]

# %% [markdown]
# ### Statistiques sur les tailles des documents

# %%
df_explo['Length'].describe()
# Out:
# count    21459.000000
# mean         9.327275
# std          5.161167
# min          1.000000
# 25%          5.000000
# 50%          8.000000
# 75%         12.000000
# max         35.000000
# Name: Length, dtype: float64

# %% [markdown]
# ### Distribution de la taille des documents après suppression des stopwords et de la ponctuation

# %%
trace1 = go.Histogram(
    x = df_explo['Length'],
    opacity=0.7,
    marker=dict(color='#FCA17D'),
)

data = [trace1]
layout = go.Layout(barmode='overlay',
                   title='Distribution de la taille des documents après la suppression des stopwords',
                   xaxis=dict(title='Taille du document'),
                   yaxis=dict( title='Fréquence'),
                  )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="daa4e0bc-3503-4ac8-9032-048db6da334e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("daa4e0bc-3503-4ac8-9032-048db6da334e")) {                    Plotly.newPlot(                        "daa4e0bc-3503-4ac8-9032-048db6da334e",                        [{"marker":{"color":"#FCA17D"},"opacity":0.7,"type":"histogram","x":[3,9,7,7,2,7,15,8,9,2,7,8,6,4,22,4,4,4,11,8,8,19,3,11,9,21,11,4,13,6,8,5,10,18,22,6,3,12,14,11,14,12,12,9,15,7,24,9,3,6,6,5,3,11,22,8,19,9,13,10,9,13,12,12,6,17,8,8,13,5,7,13,12,6,10,13,15,6,11,3,5,12,10,5,7,14,9,8,6,7,9,9,15,7,12,8,10,9,9,23,13,5,7,11,23,12,22,15,3,16,16,2,10,27,7,3,5,12,9,7,10,6,12,10,19,7,8,6,14,10,11,18,3,14,16,17,5,8,15,10,6,10,9,4,11,7,9,7,5,16,10,10,7,23,18,6,18,8,12,18,8,1
# ...

# %% [markdown]
# ### Word Cloud

# %%
texts = []
for i in range(0, df_explo.shape[0]):
    texts.append(df_explo['Text'][i])
words = [item for sublist in texts for item in sublist]

# %%
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                        background_color='white',
                        width=512,
                        height=384
                        ).generate(" ".join(words))
plt.imshow(wordcloud)
plt.axis('off')
#plt.savefig('graph.png')

plt.show()

# %% [markdown]
# La visualisation du wordcloud ne permet pas forcément une bonne compréhension de la fréquence des mots dans les documents dans ce cas. En effet, la librairie *WordCloud* n'affiche pas les mots correctement (par exemple, le mot feel apparaît plusieurs fois de manière étrange).

# %% [markdown]
# ### Test de la tokenization à ngrams

# %%
tokens = word_tokenize('The girls wanted to play with their parents')
bigrams = ngrams(tokens, 2)

for words in bigrams:
    print(words)
# Out:
# ('The', 'girls')
# ('girls', 'wanted')
# ('wanted', 'to')
# ('to', 'play')
# ('play', 'with')
# ('with', 'their')
# ('their', 'parents')

# %% [markdown]
# ### Vectorisation des mots du dataset

# %%
tfidf = TfidfVectorizer(stop_words='english', analyzer='word', ngram_range=(1,2))

# %% [markdown]
# Après plusieurs tests sur la taille du ngram utilisé pour la vectorisation des mots, l'option *ngram_range* a été définie à *(1,2)*.

# %% [markdown]
# ### Définition du classifier

# %%
#classifier = MultinomialNB()
classifier = LinearSVC()
#classifier = SGDClassifier(max_iter=1000, tol=1e-3)
#classifier = KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ### Définition de la pipeline

# %%
pipeline =  Pipeline([
    ('vect', tfidf), 
    ('tfidf', TfidfTransformer()), 
    ('clf', classifier)])

# %% [markdown]
# ### Split train and validation datasets

# %%
X_train, X_val, y_train, y_val = train_test_split(df['Text'], df['Emotion'], stratify=df['Emotion'], shuffle=True, test_size=0.20)

# %%
clf = pipeline.fit(X_train, y_train)

# %%
pipeline.score(X_train, y_train)
# Out:
# 0.9967961787149764

# %%
pipeline.score(X_val, y_val)
# Out:
# 0.8837371854613234

# %% [markdown]
# ### Classification report données d'entrainements

# %%
all_predictions = pipeline.predict(X_train)
print(classification_report(y_train, all_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        anger       1.00      1.00      1.00      2394
#         fear       1.00      1.00      1.00      2122
#          joy       1.00      1.00      1.00      5623
#         love       0.99      0.99      0.99      1313
#      sadness       1.00      1.00      1.00      5012
#     surprise       0.99      0.99      0.99       703
#
#     accuracy                           1.00     17167
#    macro avg       1.00      1.00      1.00     17167
# weighted avg       1.00      1.00      1.00     17167

# %% [markdown]
# ### Matrice de confusion données d'entrainement

# %%
z = confusion_matrix(all_predictions, y_train)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="1819825a-1bf1-4794-9c68-b995f155b5cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1819825a-1bf1-4794-9c68-b995f155b5cf")) {                    Plotly.newPlot(                        "1819825a-1bf1-4794-9c68-b995f155b5cf",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"type":"heatmap","x":["anger","fear","joy","love","sadness","surprise"],"y":["anger","fear","joy","love","sadness","surprise"],"z":[[
# ...

# %% [markdown]
# ### Classification report données de validation

# %%
y_pred = pipeline.predict(X_val)
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.91      0.88      0.90       599
#         fear       0.85      0.85      0.85       530
#          joy       0.89      0.92      0.91      1406
#         love       0.78      0.71      0.74       328
#      sadness       0.90      0.94      0.92      1253
#     surprise       0.82      0.68      0.74       176
#
#     accuracy                           0.88      4292
#    macro avg       0.86      0.83      0.84      4292
# weighted avg       0.88      0.88      0.88      4292

# %% [markdown]
# ### Matrice de confusion données de validation

# %%
z = confusion_matrix(y_pred, y_val)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="d7d18c2f-8deb-4ae5-87da-35b861f4c350" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7d18c2f-8deb-4ae5-87da-35b861f4c350")) {                    Plotly.newPlot(                        "d7d18c2f-8deb-4ae5-87da-35b861f4c350",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"type":"heatmap","x":["anger","fear","joy","love","sadness","surprise"],"y":["anger","fear","joy","love","sadness","surprise"],"z":[[
# ...

# %% [markdown]
# ### Observations faites sur les résulats de classfication des données de validation

# %% [markdown]
# Les résultats obtenues sur les données de la validation sont assez satisfaisants. En effet, le minimum de précision obtenu est de 76% pour la classe *Surprise*. Cependant, le modèle a certaines difficultés. Il confond le plus souvent les émotions suivantes :
# - La surprise avec la peur
# - La tristesse avec la colère
# - L'amour avec la joie

# %% [markdown]
# # Gridsearch

# %%
param_grid = [
    {
        'vect':[
            CountVectorizer(),
            HashingVectorizer(n_features=2500,alternate_sign=False),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(1,2)),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(2,3)),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(1,3))
        ],
        'clf': [
            #svm.SVC(kernel='rbf'),
            #svm.SVC(kernel='linear'),
            #svm.SVC(kernel='poly'),
            #SGDClassifier(max_iter=1000, tol=1e-3),
            #BernoulliNB(),
            #CategoricalNB(),
            #ComplementNB(),
            #GaussianNB(),
            #MultinomialNB(),
            KNeighborsClassifier(n_neighbors=6),
            KNeighborsClassifier(n_neighbors=6, weights='distance'),
        ],   
    }
]

# %% [markdown]
# - Le meilleur des modèles de SVC est **svm.SVC(kernel='linear')**.
# - Le meilleur des modèles de Naive Bayes est **ComplementNB()**.
# - Le meilleur des modèles de KNN est : .
# - Le meilleur des modèles SVC, NB, KNN et SGD est : .

# %%
grid_search = GridSearchCV(pipeline, 
                           param_grid, 
                           cv=4,
                           n_jobs=-1,
                           scoring='accuracy',
                           verbose=1,
                           return_train_score=True)
 
grid_res = grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits

# %%
joblib.dump(grid_res, r'C:\Users\straw\Desktop\AIS\ProjectPool 2\Roue-des-emotions\Output\models\nlp_models.pkl')
# Out:
# ['C:\\Users\\straw\\Desktop\\AIS\\ProjectPool 2\\Roue-des-emotions\\Output\\models\\nlp_models.pkl']

# %%
print('Best Estimator :',grid_res.best_estimator_)
# Out:
# Best Estimator : Pipeline(steps=[('vect',
#                  TfidfVectorizer(ngram_range=(1, 2), stop_words='english')),
#                 ('tfidf', TfidfTransformer()), ('clf', SGDClassifier())])

# %%
print('Best Score :', grid_res.best_score_)
# Out:
# Best Score : 0.8802935819199812

# %%
print('Best parameters :',grid_res.best_params_)
# Out:
# Best parameters : {'clf': SGDClassifier(), 'vect': TfidfVectorizer(ngram_range=(1, 2), stop_words='english')}

# %%
best_pred = grid_res.predict(X_val)
print('Percentage correct: ', 100*np.sum(best_pred == y_val)/len(y_val))
# Out:
# Percentage correct:  87.65144454799628

# %%
z = confusion_matrix(best_pred, y_val)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="75806382-9fd0-4a47-9526-5ffac40723ff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75806382-9fd0-4a47-9526-5ffac40723ff")) {                    Plotly.newPlot(                        "75806382-9fd0-4a47-9526-5ffac40723ff",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"reversescale":false,"showscale":true,"type":"heatmap","x":["anger","fear","joy","love","sadness","surprise"],"y":["anger","fear","joy","love","sadness","surprise"],"z":[[
# ...

# %%
print(classification_report(y_val, best_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.89      0.84      0.86       599
#         fear       0.91      0.82      0.86       530
#          joy       0.87      0.92      0.90      1406
#         love       0.80      0.70      0.74       328
#      sadness       0.89      0.94      0.91      1253
#     surprise       0.81      0.70      0.75       176
#
#     accuracy                           0.88      4292
#    macro avg       0.86      0.82      0.84      4292
# weighted avg       0.88      0.88      0.87      4292

# %% [markdown]
# # Base de données text_emotion.csv

# %%
# Import des données
df2 = pd.read_csv(r'C:\Users\straw\Desktop\AIS\ProjectPool 2\Roue-des-emotions\Data\text_emotion.csv', sep=',')
df2
# Out:
#          tweet_id   sentiment         author  \
# 0      1956967341       empty     xoshayzers
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043         joy       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   author     40000 non-null  object
#  3   content    40000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
df2 = df2[df2['sentiment'].isin(['joy', 'sadness', 'love', 'surprise', 'anger'])].reset_index(drop=True)

# %% [markdown]
# ## Exploration des données de test

# %%
S2 = df2['sentiment'].value_counts()
S2
# Out:
# joy         5209
# sadness     5165
# love        3842
# surprise    2187
# anger        110
# Name: sentiment, dtype: int64

# %%
sns.countplot(x='sentiment', data=df2, palette='hls')
plt.title('Distribution des émotions dans le dataset test')
plt.show()

# %%
fig = px.pie(S2, values=S2.values, names=S2.index, title='Distribution des émotions dans le dataset')
fig.show()
# Out:
# <div>                            <div id="40c81dc7-c4f4-4a26-a829-51e3c5851a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40c81dc7-c4f4-4a26-a829-51e3c5851a1b")) {                    Plotly.newPlot(                        "40c81dc7-c4f4-4a26-a829-51e3c5851a1b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["joy","sadness","love","surprise","anger"],"legendgroup":"","name":"","showlegend":true,"type":"pie","values":[5209,5165,3842,2187,110]}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":
# ...

# %%
lowers = []
for i in range(0, df2.shape[0]):
    lowers.append(df2['content'][i].lower())

df2['content'] = lowers

# %%
df2['content'] = df2['content'].apply(word_tokenize)
stopW = stopwords.words('english')
stopW.extend(list(string.punctuation))

# %%
def remove_stopwords(sent):
    tokens_without_stopW = [word for word in sent if word not in stopW]
    return tokens_without_stopW

df2['content'] = df2['content'].apply(lambda sent: remove_stopwords(sent))

# %%
wnl = WordNetLemmatizer()
def lemmatize(sent, join=True):
    tokens = [wnl.lemmatize(wnl.lemmatize(wnl.lemmatize(w,'v'),'n'),'a') for w in sent]
    if join:
        return ' '.join(tokens)
    else:
        return tokens

df2_explo = copy.deepcopy(df2)

df2['content'] = df2['content'].apply(lambda sent: lemmatize(sent))

df2_explo['content'] = df2_explo['content'].apply(lambda sent: lemmatize(sent, join=False))

# %%
df2_explo['Length'] = df2_explo['content'].apply(len)

df2_explo['Length'].describe()
# Out:
# count    16513.000000
# mean         8.669836
# std          4.313114
# min          0.000000
# 25%          5.000000
# 50%          8.000000
# 75%         12.000000
# max         28.000000
# Name: Length, dtype: float64

# %%
trace1 = go.Histogram(
    x = df2_explo['Length'],
    text = df2_explo.sentiment,
    opacity=0.6,
)

data = [trace1]
layout = go.Layout(barmode='overlay',
                   title='Distribution de la taille des documents après la suppression des stopwords',
                   xaxis=dict(title='Taille du document'),
                   yaxis=dict( title='Fréquence'),
                  )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="115abf90-3e96-413d-865f-c3b0ee7df135" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("115abf90-3e96-413d-865f-c3b0ee7df135")) {                    Plotly.newPlot(                        "115abf90-3e96-413d-865f-c3b0ee7df135",                        [{"opacity":0.6,"text":["sadness","sadness","sadness","sadness","sadness","sadness","sadness","surprise","sadness","love","sadness","sadness","sadness","sadness","sadness","sadness","joy","sadness","sadness","sadness","sadness","sadness","sadness","sadness","joy","joy","sadness","sadness","sadness","love","sadness","sadness","sadness","sadness","sadness","sadness","sadness","sadness","love","sadness","joy","sadness","love","sadness","sadness","sadness","sadness","
# ...

# %%
texts = []
for i in range(0, df2_explo.shape[0]):
    texts.append(df2_explo['content'][i])
words = [item for sublist in texts for item in sublist]

count_of_words = Counter(words)
df_words_count = pd.DataFrame(list(count_of_words.items()),columns = ['Word','Count'])

plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                        background_color='white',
                        width=512,
                        height=384
                        ).generate(" ".join(words))
plt.imshow(wordcloud)
plt.axis('off')

plt.show()

# %%
X_test = df2['content']
y_test = df2['sentiment']

# %%
best_pred = grid_res.predict(X_test)
print('Percentage correct: ', 100*np.sum(best_pred == y_test)/len(y_test))
# Out:
# Percentage correct:  41.30079331435839

# %%
titles_options = [("Confusion matrix", None)]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(grid_res, X_test, y_test,
                                 cmap=plt.cm.viridis,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title,'for test set')
    print(disp.confusion_matrix)
    print()

plt.show()
# Out:
# Confusion matrix for test set
# [[  13    1   54    0   42    0]
#  [   0    0    0    0    0    0]
#  [ 121   41 3949  118  874  106]
#  [  80   33 2736  270  644   79]
#  [ 303   55 2164   85 2527   31]
#  [  91   50 1336   39  610   61]]
