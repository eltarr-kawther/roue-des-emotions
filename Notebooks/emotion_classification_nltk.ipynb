# %% [markdown]
# # La roue des émotions

# %%
import pandas as pd
import string
import numpy as np

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk import ngrams

import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import copy
from collections import Counter

from plotly.offline import init_notebook_mode, iplot, plot
import plotly as py
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer,TfidfTransformer,HashingVectorizer
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

from sklearn.svm import LinearSVC
from sklearn import svm
from sklearn.naive_bayes import BernoulliNB, CategoricalNB, ComplementNB, GaussianNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier

from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix, classification_report, plot_confusion_matrix

import joblib
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import nltk
nltk.download("stopwords")
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\keltarr\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\keltarr\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\keltarr\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv(r'C:\Users\straw\Desktop\AIS\ProjectPool 2\Roue-des-emotions\Data\emotions_final.csv', sep=',')
df
# Out:
#                                                     Text  Emotion
# 0                                i didnt feel humiliated  sadness
# 1      i can go from feeling so hopeless to so damned...  sadness
# 2       im grabbing a minute to post i feel greedy wrong    anger
# 3      i am ever feeling nostalgic about the fireplac...     love
# 4                                   i am feeling grouchy    anger
# ...                                                  ...      ...
# 21454               Melissa stared at her friend in dism     fear
# 21455  Successive state elections have seen the gover...     fear
# 21456               Vincent was irritated but not dismay     fear
# 21457  Kendall-Hume turned back to face the dismayed ...     fear
# 21458                    I am dismayed , but not surpris     fear
#
# [21459 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21459 entries, 0 to 21458
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Text     21459 non-null  object
#  1   Emotion  21459 non-null  object
# dtypes: object(2)
# memory usage: 335.4+ KB

# %% [markdown]
# ### Classes du dataset

# %%
S = df['Emotion'].value_counts()
S
# Out:
# joy         7029
# sadness     6265
# anger       2993
# fear        2652
# love        1641
# surprise     879
# Name: Emotion, dtype: int64

# %% [markdown]
# #### Countplot

# %%
sns.countplot(x='Emotion', data=df, palette='hls')
plt.title('Distribution des émotions dans le dataset')
plt.show()

# %% [markdown]
# #### Piechart

# %%
fig = px.pie(S, values=S.values, names=S.index, title='Distribution des émotions dans le dataset')
fig.show()
# Out:
# <div>                            <div id="76f555d6-87db-4b8c-b00c-fd0b2c743f76" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76f555d6-87db-4b8c-b00c-fd0b2c743f76")) {                    Plotly.newPlot(                        "76f555d6-87db-4b8c-b00c-fd0b2c743f76",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "index=%{label}<br>value=%{value}<extra></extra>", "labels": ["joy", "sadness", "anger", "fear", "love", "surprise"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [7029, 6265, 2993, 2652, 1641, 879]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"ou ...

# %% [markdown]
# ### Normalisation

# %%
lowers = []
for i in range(0, df.shape[0]):
    lowers.append(df['Text'][i].lower())

# %%
df['Text'] = lowers
df['Text']
# Out:
# 0                                  i didnt feel humiliated
# 1        i can go from feeling so hopeless to so damned...
# 2         im grabbing a minute to post i feel greedy wrong
# 3        i am ever feeling nostalgic about the fireplac...
# 4                                     i am feeling grouchy
#                                ...
# 21454                 melissa stared at her friend in dism
# 21455    successive state elections have seen the gover...
# 21456                 vincent was irritated but not dismay
# 21457    kendall-hume turned back to face the dismayed ...
# 21458                      i am dismayed , but not surpris
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Tokénization

# %%
df['Text'] = df['Text'].apply(word_tokenize)
df['Text']
# Out:
# 0                             [i, didnt, feel, humiliated]
# 1        [i, can, go, from, feeling, so, hopeless, to, ...
# 2        [im, grabbing, a, minute, to, post, i, feel, g...
# 3        [i, am, ever, feeling, nostalgic, about, the, ...
# 4                                [i, am, feeling, grouchy]
#                                ...
# 21454         [melissa, stared, at, her, friend, in, dism]
# 21455    [successive, state, elections, have, seen, the...
# 21456          [vincent, was, irritated, but, not, dismay]
# 21457    [kendall-hume, turned, back, to, face, the, di...
# 21458              [i, am, dismayed, ,, but, not, surpris]
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Suppression des stop words

# %%
stopW = stopwords.words('english')
stopW.extend(list(string.punctuation))

# %%
def remove_stopwords(sent):
    tokens_without_stopW = [word for word in sent if word not in stopW]
    return tokens_without_stopW

# %%
df['Text'] = df['Text'].apply(lambda sent: remove_stopwords(sent))

# %% [markdown]
# ### Stemming et Lemmatization

# %%
wnl = WordNetLemmatizer()

# %%
def lemmatize(sent, join=True):
    tokens = [wnl.lemmatize(wnl.lemmatize(wnl.lemmatize(w,'v'),'n'),'a') for w in sent]
    if join:
        return ' '.join(tokens)
    else:
        return tokens

# %%
df_explo = copy.deepcopy(df)

# %%
df['Text'] = df['Text'].apply(lambda sent: lemmatize(sent))

# %%
df_explo['Text'] = df_explo['Text'].apply(lambda sent: lemmatize(sent, join=False))

# %%
df_explo['Text']
# Out:
# 0                                 [didnt, feel, humiliate]
# 1        [go, feel, hopeless, damn, hopeful, around, so...
# 2            [im, grab, minute, post, feel, greedy, wrong]
# 3        [ever, feel, nostalgic, fireplace, know, still...
# 4                                          [feel, grouchy]
#                                ...
# 21454                        [melissa, star, friend, dism]
# 21455    [successive, state, election, see, govern, par...
# 21456                          [vincent, irritate, dismay]
# 21457       [kendall-hume, turn, back, face, dismay, coup]
# 21458                                    [dismay, surpris]
# Name: Text, Length: 21459, dtype: object

# %% [markdown]
# ### Exploration des données

# %%
df_explo['Length'] = df_explo['Text'].apply(len)
df_explo
# Out:
#                                                     Text  Emotion  Length
# 0                               [didnt, feel, humiliate]  sadness       3
# 1      [go, feel, hopeless, damn, hopeful, around, so...  sadness       9
# 2          [im, grab, minute, post, feel, greedy, wrong]    anger       7
# 3      [ever, feel, nostalgic, fireplace, know, still...     love       7
# 4                                        [feel, grouchy]    anger       2
# ...                                                  ...      ...     ...
# 21454                      [melissa, star, friend, dism]     fear       4
# 21455  [successive, state, election, see, govern, par...     fear       9
# 21456                        [vincent, irritate, dismay]     fear       3
# 21457     [kendall-hume, turn, back, face, dismay, coup]     fear       6
# 21458                                  [dismay, surpris]     fear       2
#
# [21459 rows x 3 columns]

# %% [markdown]
# ### Statistiques sur les tailles des documents

# %%
df_explo['Length'].describe()
# Out:
# count    21459.000000
# mean         9.327275
# std          5.161167
# min          1.000000
# 25%          5.000000
# 50%          8.000000
# 75%         12.000000
# max         35.000000
# Name: Length, dtype: float64

# %% [markdown]
# ### Distribution de la taille des documents après suppression des stopwords

# %%
trace1 = go.Histogram(
    x = df_explo['Length'],
    text = df_explo.Emotion,
    opacity=0.6,
)

data = [trace1]
layout = go.Layout(barmode='overlay',
                   title='Distribution de la taille des documents après la suppression des stopwords',
                   xaxis=dict(title='Taille du document'),
                   yaxis=dict( title='Fréquence'),
                  )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="c1eb87dd-da50-424e-81a1-6917f9956d95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1eb87dd-da50-424e-81a1-6917f9956d95")) {                    Plotly.newPlot(                        "c1eb87dd-da50-424e-81a1-6917f9956d95",                        [{"opacity": 0.6, "text": ["sadness", "sadness", "anger", "love", "anger", "sadness", "surprise", "fear", "joy", "love", "sadness", "joy", "anger", "sadness", "joy", "joy", "sadness", "sadness", "sadness", "fear", "anger", "fear", "joy", "joy", "anger", "sadness", "sadness", "sadness", "anger", "joy", "joy", "fear", "surprise", "anger", "joy", "joy", "joy", "joy", "anger", "joy", "joy", "joy", "joy", "joy", "sadness", "sadness", "joy", "love", "joy", "anger", "joy", "sadness", "anger", "fear", "joy", "sadness", "sadness", "surprise", "joy", "joy", "joy", "love", "fear", "fear", "surprise", "anger", "anger", "sadness", "love", "joy", "sadness", "sadness", "joy", "sadness", "sadness", "sadness", "joy", "joy", "joy", "anger", "sadness", "anger", "anger", "anger", "joy", "joy", "joy", "joy", "sadness", "fear", "love", "anger", "sadness", "anger", "love", "sadness", "joy", "joy", "sadness", "anger", "love", "joy", "joy", "joy", "sadness", "joy", "joy", "joy", "joy", "sadness", "joy", "joy", "love", "sadness", "sadness", "joy", "joy", "sadness", "joy", "joy", "fear", "fear", "fear", "sadness", "love", "joy", "joy", "love", "fear", "surprise", "joy", "joy", "joy", "joy", "anger", "fear", "joy", "anger", "love", "anger", "sadness", "joy", "sadness", "anger", "joy", "surprise", "sadness", "anger", "anger", "sadness", "joy", "fear", "joy", "joy", "fear", "sadness", "surprise", "surprise", "joy", "anger", "fear", "anger", "sadness", "anger", "sadness", "fear", "sadness", "joy", "surprise", "fear", "joy", "anger", "joy", "anger", "joy", "fear", "fear", "sadness", "joy", "joy", "sadness", "surprise", "joy", "fear", "joy", "sadness", "joy", "joy", "joy", "fear", "joy", "surprise", "joy", "anger", "sadness", "sadness", "joy", "anger", "sadness", "joy", "joy", "surprise", "joy", "fear", "joy", "fear", "sadness", "fear", "love", "sadness", "fear", "love", "sadness", "sadness", "anger", "joy", "love", "anger", "sadness", "surprise", "anger", "joy", "sadness", "anger", "joy", "joy", "joy", "joy", "joy", "sadness", "joy", "love", "joy", "sadness", "anger", "surprise", "joy", "anger", "joy", "love", "sadness", "sadness", "joy", "sadness", "sadness", "joy", "sadness", "joy", "joy", "joy", "fear", "sadness", "anger", "sadness", "anger", "love", "joy", "love", "sadness", "joy", "joy", "joy", "sadness", "joy", "sadness", "anger", "love", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "fear", "joy", "sadness", "sadness", "joy", "love", "sadness", "anger", "sadness", "love", "joy", "joy", "joy", "sadness", "joy", "sadness", "joy", "joy", "joy", "sadness", "sadness", "sadness", "love", "fear", "sadness", "fear", "joy", "joy", "fear", "joy", "anger", "anger", "love", "sadness", "surprise", "joy", "anger", "sadness", "sadness", "anger", "love", "surprise", "sadness", "love", "joy", "anger", "joy", "sadness", "sadness", "joy", "joy", "fear", "sadness", "anger", "joy", "love", "joy", "joy", "joy", "joy", "joy", "love", "joy", "fear", "fear", "joy", "joy", "anger", "joy", "joy", "joy", "sadness", "surprise", "joy", "joy", "sadness", "surprise", "joy", "fear", "joy", "anger", "love", "anger", "fear", "surprise", "joy", "anger", "sadness", "sadness", "sadness", "fear", "joy", "fear", "joy", "anger", "sadness", "love", "anger", "sadness", "love", "love", "joy", "sadness", "joy", "joy", "anger", "joy", "love", "joy", "joy", "sadness", "surprise", "joy", "joy", "sadness", "surprise", "anger", "joy", "joy",  ...

# %% [markdown]
# ### Word Cloud

# %%
texts = []
for i in range(0, df_explo.shape[0]):
    texts.append(df_explo['Text'][i])
words = [item for sublist in texts for item in sublist]

# %%
count_of_words = Counter(words)
df_words_count = pd.DataFrame(list(count_of_words.items()),columns = ['Word','Count'])

# %%
plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                        background_color='white',
                        width=512,
                        height=384
                        ).generate(" ".join(words))
plt.imshow(wordcloud)
plt.axis('off')
#plt.savefig('graph.png')

plt.show()

# %%
tokens = word_tokenize('The girls wanted to play with their parents')
bigrams = ngrams(tokens, 2)

for words in bigrams:
    print(words)
# Out:
# ('The', 'girls')
# ('girls', 'wanted')
# ('wanted', 'to')
# ('to', 'play')
# ('play', 'with')
# ('with', 'their')
# ('their', 'parents')

# %% [markdown]
# ### Vectorisation des mots du dataset

# %%
tfidf = TfidfVectorizer(stop_words='english',analyzer='word', ngram_range=(1,2))

# %% [markdown]
# ### Définition du classifier

# %%
#classifier = MultinomialNB()
classifier = LinearSVC()
#classifier = SGDClassifier(max_iter=1000, tol=1e-3)
#classifier = KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ### Définition de la pipeline

# %%
pipeline =  Pipeline([
    ('vect', tfidf), 
    ('tfidf', TfidfTransformer()), 
    ('clf', classifier)])

# %% [markdown]
# ### Split train and validation datasets

# %%
X_train, X_val, y_train, y_val = train_test_split(df['Text'], df['Emotion'], stratify=df['Emotion'], shuffle=True, test_size=0.20)

# %%
clf = pipeline.fit(X_train, y_train)

# %%
pipeline.score(X_train, y_train)
# Out:
# 0.996213665754063

# %%
pipeline.score(X_val, y_val)
# Out:
# 0.8867660764212488

# %% [markdown]
# ### Classification report données d'entrainements

# %%
all_predictions = pipeline.predict(X_train)
print(classification_report(y_train, all_predictions))
# Out:
#               precision    recall  f1-score   support
#
#        anger       1.00      1.00      1.00      2394
#         fear       0.99      0.99      0.99      2122
#          joy       1.00      1.00      1.00      5623
#         love       0.99      0.99      0.99      1313
#      sadness       1.00      1.00      1.00      5012
#     surprise       0.99      0.99      0.99       703
#
#     accuracy                           1.00     17167
#    macro avg       0.99      0.99      0.99     17167
# weighted avg       1.00      1.00      1.00     17167

# %% [markdown]
# ### Matrice de confusion données d'entrainement

# %%
z = confusion_matrix(all_predictions, y_train)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="34084490-0bd1-4804-98e2-99ac30a47dc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34084490-0bd1-4804-98e2-99ac30a47dc5")) {                    Plotly.newPlot(                        "34084490-0bd1-4804-98e2-99ac30a47dc5",                        [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "reversescale": false, "showscale": true, "type": "heatmap", "x": ["anger", "fear", "joy", "love", "sadness", "surprise"], "y": ["anger", "fear", "joy", "love", "sadness", "surprise"], "z": [[2385, 5, 0, 0, 2, 0], [2, 2111, 0, 0, 3, 7], [2, 0, 5606, 14, 0, 1], [0, 0, 13, 1299, 1, 0], [5, 1, 3, 0, 5006, 0], [0, 5, 1, 0, 0, 695]]}],                        {"annotations": [{"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2385", "x": "anger", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "5", "x": "fear", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "joy", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "love", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "sadness", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "surprise", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "anger", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2111", "x": "fear", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "joy", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "love", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "3", "x": "sadness", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "7", "x": "surprise", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "anger", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "fear", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "5606", "x": "joy", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "14", "x": "love", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "sadness", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "surprise", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "anger", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "fear", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "13", "x": "joy", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1299", "x": "love", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "sadness", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, ...

# %% [markdown]
# ### Classification report données de validation

# %%
y_pred = pipeline.predict(X_val)
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.92      0.85      0.89       599
#         fear       0.88      0.86      0.87       530
#          joy       0.88      0.93      0.91      1406
#         love       0.81      0.70      0.75       328
#      sadness       0.90      0.94      0.92      1253
#     surprise       0.82      0.72      0.77       176
#
#     accuracy                           0.89      4292
#    macro avg       0.87      0.83      0.85      4292
# weighted avg       0.89      0.89      0.89      4292

# %% [markdown]
# ### Matrice de confusion données de validation

# %%
z = confusion_matrix(y_pred, y_val)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="66f647c7-af18-4d0c-938d-6e914270f032" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66f647c7-af18-4d0c-938d-6e914270f032")) {                    Plotly.newPlot(                        "66f647c7-af18-4d0c-938d-6e914270f032",                        [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "reversescale": false, "showscale": true, "type": "heatmap", "x": ["anger", "fear", "joy", "love", "sadness", "surprise"], "y": ["anger", "fear", "joy", "love", "sadness", "surprise"], "z": [[512, 14, 8, 5, 16, 1], [14, 454, 6, 0, 14, 29], [31, 15, 1306, 79, 37, 12], [2, 3, 40, 229, 7, 0], [39, 29, 35, 15, 1179, 8], [1, 15, 11, 0, 0, 126]]}],                        {"annotations": [{"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "512", "x": "anger", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "14", "x": "fear", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "8", "x": "joy", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "5", "x": "love", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "16", "x": "sadness", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "surprise", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "14", "x": "anger", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "454", "x": "fear", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "6", "x": "joy", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "0", "x": "love", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "14", "x": "sadness", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "29", "x": "surprise", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "31", "x": "anger", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "15", "x": "fear", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "1306", "x": "joy", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "79", "x": "love", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "37", "x": "sadness", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "12", "x": "surprise", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "anger", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "3", "x": "fear", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "40", "x": "joy", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "229", "x": "love", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "7", "x": "sadness", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, " ...

# %% [markdown]
# ### Observations faites sur les résulats de classfication des données de validation

# %% [markdown]
# Les résultats obtenues sur les données de la validation sont assez satisfaisants. En effet, le minimum de précision obtenu est de 76% pour la classe *Surprise*. Cependant, le modèle a certaines difficultés. Il confond le plus souvent les émotions suivantes :
# - La surprise avec la peur
# - La tristesse avec la colère
# - L'amour avec la joie

# %% [markdown]
# # Gridsearch

# %%
param_grid = [
    {
        'vect':[
            CountVectorizer(),
            HashingVectorizer(n_features=2500,alternate_sign=False),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(1,2)),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(2,3)),
            TfidfVectorizer(stop_words='english',analyzer='word',ngram_range=(1,3))
        ],
        'clf': [
            #svm.SVC(kernel='rbf'),
            svm.SVC(kernel='linear'),
            #svm.SVC(kernel='poly'),
            SGDClassifier(max_iter=1000, tol=1e-3),
            #BernoulliNB(),
            #CategoricalNB(),
            #ComplementNB(),
            #GaussianNB(),
            #MultinomialNB(),
            KNeighborsClassifier(n_neighbors=6, weights='distance'),
        ],   
    }
]

# %% [markdown]
# - Le meilleur des modèles de SVC est **svm.SVC(kernel='linear')**.
# - Le meilleur des modèles de Naive Bayes est **ComplementNB()**.
# - Le meilleur des modèles de KNN est : .
# - Le meilleur des modèles SVC, NB, KNN et SGD est : .

# %%
grid_search = GridSearchCV(pipeline, 
                           param_grid, 
                           cv=3,
                           n_jobs=-1,
                           scoring='accuracy',
                           verbose=1,
                           return_train_score=True)
 
grid_res = grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 15 candidates, totalling 45 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:  6.0min finished

# %%
joblib.dump(grid_res, r'C:\Users\straw\Desktop\AIS\ProjectPool 2\Roue-des-emotions\Output\models\nlp_models.pkl')
# Out:
# ['C:\\Users\\straw\\Desktop\\AIS\\ProjectPool 2\\Roue-des-emotions\\Output\\models\\nlp_models.pkl']

# %%
print('Best Estimator :',grid_res.best_estimator_)
# Out:
# Best Estimator : Pipeline(steps=[('vect',
#                  TfidfVectorizer(ngram_range=(1, 2), stop_words='english')),
#                 ('tfidf', TfidfTransformer()), ('clf', SGDClassifier())])

# %%
print('Best Score :', grid_res.best_score_)
# Out:
# Best Score : 0.8760992684338836

# %%
print('Best parameters :',grid_res.best_params_)
# Out:
# Best parameters : {'clf': SGDClassifier(), 'vect': TfidfVectorizer(ngram_range=(1, 2), stop_words='english')}

# %%
best_pred = grid_res.predict(X_val)
print('Percentage correct: ', 100*np.sum(best_pred == y_val)/len(y_val))
# Out:
# Percentage correct:  88.67660764212488

# %%
z = confusion_matrix(best_pred, y_val)

x = list(np.unique(df.Emotion))
y =  list(np.unique(df.Emotion))

# change each element of z to type string for annotations
z_text = [[str(y) for y in x] for x in z]

# set up figure 
fig = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

# add custom xaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=0.5,
                        y=-0.15,
                        showarrow=False,
                        text="Predicted value",
                        xref="paper",
                        yref="paper"))

# add custom yaxis title
fig.add_annotation(dict(font=dict(color="black",size=14),
                        x=-0.35,
                        y=0.5,
                        showarrow=False,
                        text="Real value",
                        textangle=-90,
                        xref="paper",
                        yref="paper"))

# adjust margins to make room for yaxis title
fig.update_layout(margin=dict(t=50, l=200))

# add colorbar
fig['data'][0]['showscale'] = True
fig.show()
# Out:
# <div>                            <div id="6a0d05fb-82bf-49fd-85eb-b5606931bd31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a0d05fb-82bf-49fd-85eb-b5606931bd31")) {                    Plotly.newPlot(                        "6a0d05fb-82bf-49fd-85eb-b5606931bd31",                        [{"colorscale": [[0.0, "#440154"], [0.1111111111111111, "#482878"], [0.2222222222222222, "#3e4989"], [0.3333333333333333, "#31688e"], [0.4444444444444444, "#26828e"], [0.5555555555555556, "#1f9e89"], [0.6666666666666666, "#35b779"], [0.7777777777777778, "#6ece58"], [0.8888888888888888, "#b5de2b"], [1.0, "#fde725"]], "reversescale": false, "showscale": true, "type": "heatmap", "x": ["anger", "fear", "joy", "love", "sadness", "surprise"], "y": ["anger", "fear", "joy", "love", "sadness", "surprise"], "z": [[509, 14, 7, 7, 15, 1], [17, 447, 5, 1, 13, 31], [33, 18, 1319, 88, 31, 12], [2, 2, 34, 219, 3, 0], [37, 33, 31, 13, 1190, 10], [1, 16, 10, 0, 1, 122]]}],                        {"annotations": [{"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "509", "x": "anger", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "14", "x": "fear", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "7", "x": "joy", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "7", "x": "love", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "15", "x": "sadness", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "surprise", "xref": "x", "y": "anger", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "17", "x": "anger", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "447", "x": "fear", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "5", "x": "joy", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "1", "x": "love", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "13", "x": "sadness", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "31", "x": "surprise", "xref": "x", "y": "fear", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "33", "x": "anger", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "18", "x": "fear", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#000000"}, "showarrow": false, "text": "1319", "x": "joy", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "88", "x": "love", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "31", "x": "sadness", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "12", "x": "surprise", "xref": "x", "y": "joy", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "anger", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "2", "x": "fear", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "34", "x": "joy", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "219", "x": "love", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "3", "x": "sadness", "xref": "x", "y": "love", "yref": "y"}, {"font": {"color": "#FFFFFF"},  ...

# %%
print(classification_report(y_val, best_pred))
# Out:
#               precision    recall  f1-score   support
#
#        anger       0.92      0.85      0.88       599
#         fear       0.87      0.84      0.86       530
#          joy       0.88      0.94      0.91      1406
#         love       0.84      0.67      0.74       328
#      sadness       0.91      0.95      0.93      1253
#     surprise       0.81      0.69      0.75       176
#
#     accuracy                           0.89      4292
#    macro avg       0.87      0.82      0.84      4292
# weighted avg       0.89      0.89      0.88      4292

# %% [markdown]
# # Base de données text_emotion.csv

# %%
# Import des données
df2 = pd.read_csv(r'C:\Users\keltarr\Desktop\Roue des émotions\Data\text_emotion.csv', sep=',')
df2
# Out:
#          tweet_id   sentiment         author  \
# 0      1956967341       empty     xoshayzers
# 1      1956967666     sadness      wannamama
# 2      1956967696     sadness      coolfunky
# 3      1956967789  enthusiasm    czareaquino
# 4      1956968416     neutral      xkilljoyx
# ...           ...         ...            ...
# 39995  1753918954     neutral  showMe_Heaven
# 39996  1753919001        love       drapeaux
# 39997  1753919005        love       JenniRox
# 39998  1753919043         joy       ipdaman1
# 39999  1753919049        love    Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# ...                                                  ...
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 4 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   40000 non-null  int64
#  1   sentiment  40000 non-null  object
#  2   author     40000 non-null  object
#  3   content    40000 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %%
df2 = df2[df2['sentiment'].isin(['joy', 'sadness', 'love', 'surprise', 'anger'])].reset_index(drop=True)

# %% [markdown]
# ## Exploration des données de test

# %%
S2 = df2['sentiment'].value_counts()
S2
# Out:
# joy         5209
# sadness     5165
# love        3842
# surprise    2187
# anger        110
# Name: sentiment, dtype: int64

# %%
sns.countplot(x='sentiment', data=df2, palette='hls')
plt.title('Distribution des émotions dans le dataset test')
plt.show()

# %%
fig = px.pie(S2, values=S2.values, names=S2.index, title='Distribution des émotions dans le dataset')
fig.show()
# Out:
# <div>                            <div id="524e4e58-ebf5-45a6-8eaf-6aaa97b19976" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("524e4e58-ebf5-45a6-8eaf-6aaa97b19976")) {                    Plotly.newPlot(                        "524e4e58-ebf5-45a6-8eaf-6aaa97b19976",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "index=%{label}<br>value=%{value}<extra></extra>", "labels": ["joy", "sadness", "love", "surprise", "anger"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [5209, 5165, 3842, 2187, 110]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0 ...

# %%
lowers = []
for i in range(0, df2.shape[0]):
    lowers.append(df2['content'][i].lower())

df2['content'] = lowers

# %%
lowers[0]
# Out:
# 'layin n bed with a headache  ughhhh...waitin on your call...'

# %%
df2['content'] = df2['content'].apply(word_tokenize)
stopW = stopwords.words('english')
stopW.extend(list(string.punctuation))

# %%
def remove_stopwords(sent):
    tokens_without_stopW = [word for word in sent if word not in stopW]
    return tokens_without_stopW

df2['content'] = df2['content'].apply(lambda sent: remove_stopwords(sent))

# %%
df2['content']
# Out:
# 0        [layin, n, bed, headache, ughhhh, ..., waitin,...
# 1            [funeral, ceremony, ..., gloomy, friday, ...]
# 2        [sleep, im, thinking, old, friend, want, 's, m...
# 3                        [charviray, charlene, love, miss]
# 4                 [kelcouch, 'm, sorry, least, 's, friday]
#                                ...
# 16508                      [succesfully, following, tayla]
# 16509                          [happy, mothers, day, love]
# 16510    [happy, mother, 's, day, mommies, woman, man, ...
# 16511    [niariley, wassup, beautiful, follow, peep, ne...
# 16512    [mopedronin, bullet, train, tokyo, gf, visitin...
# Name: content, Length: 16513, dtype: object

# %%
wnl = WordNetLemmatizer()
def lemmatize(sent, join=True):
    tokens = [wnl.lemmatize(wnl.lemmatize(wnl.lemmatize(w,'v'),'n'),'a') for w in sent]
    if join:
        return ' '.join(tokens)
    else:
        return tokens

df2_explo = copy.deepcopy(df2)

df2['content'] = df2['content'].apply(lambda sent: lemmatize(sent))

df2_explo['content'] = df2_explo['content'].apply(lambda sent: lemmatize(sent, join=False))

# %%
df2['content'][0]
# Out:
# 'layin n bed headache ughhhh ... waitin call ...'

# %%
df2_explo['Length'] = df2_explo['content'].apply(len)

df2_explo['Length'].describe()
# Out:
# count    16513.000000
# mean         8.670018
# std          4.313205
# min          0.000000
# 25%          5.000000
# 50%          8.000000
# 75%         12.000000
# max         28.000000
# Name: Length, dtype: float64

# %%
trace1 = go.Histogram(
    x = df2_explo['Length'],
    text = df2_explo.sentiment,
    opacity=0.6,
)

data = [trace1]
layout = go.Layout(barmode='overlay',
                   title='Distribution de la taille des documents après la suppression des stopwords',
                   xaxis=dict(title='Taille du document'),
                   yaxis=dict( title='Fréquence'),
                  )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>                            <div id="78fde6a8-d8b6-43d5-9946-c9410513e5e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78fde6a8-d8b6-43d5-9946-c9410513e5e8")) {                    Plotly.newPlot(                        "78fde6a8-d8b6-43d5-9946-c9410513e5e8",                        [{"opacity": 0.6, "text": ["sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "joy", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "joy", "joy", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "joy", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "surprise", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "surprise", "sadness", "surprise", "sadness", "surprise", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "joy", "joy", "sadness", "sadness", "sadness", "joy", "joy", "sadness", "surprise", "surprise", "surprise", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "surprise", "sadness", "surprise", "sadness", "joy", "sadness", "sadness", "sadness", "joy", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "joy", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "joy", "sadness", "surprise", "surprise", "joy", "sadness", "love", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "love", "love", "sadness", "sadness", "sadness", "surprise", "joy", "surprise", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "anger", "surprise", "sadness", "sadness", "sadness", "sadness", "sadness", "joy", "sadness", "joy", "sadness", "sadness", "joy", "anger", "sadness", "surprise", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "joy", "sadness", "sadness", "surprise", "sadness", "surprise", "sadness", "sadness", "sadness", "sadness", "joy", "sadness", "sadness", "sadness", "joy", "surprise", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "surprise", "sadness", "sadness", "anger", "sadness", "love", "joy", "joy", "sadness", "sadness", "sadness", "sadness", "surprise", "surprise", "surprise", "love", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "joy", "sadness", "love", "sadness", "sadness", "love", "joy", "sadness", "sadness", "surprise", "love", "joy", "sadness", "sadness", "sadness", "joy", "surprise", "surprise", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "sadness", "sadness", "love", "surprise", "love", "joy", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "sadness", "sadness", "sadness", "love", "sadness", "surprise", "surprise", "sadness", "surprise", "surprise", "love", "love", "sadness", "surprise", "sadness", "surprise", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", "sadness", "sadness", "surprise", "sadness", "sadness", " ...

# %%
texts = []
for i in range(0, df2_explo.shape[0]):
    texts.append(df2_explo['content'][i])
words = [item for sublist in texts for item in sublist]

count_of_words = Counter(words)
df_words_count = pd.DataFrame(list(count_of_words.items()),columns = ['Word','Count'])

plt.subplots(figsize=(8,8))
wordcloud = WordCloud(
                        background_color='white',
                        width=512,
                        height=384
                        ).generate(" ".join(words))
plt.imshow(wordcloud)
plt.axis('off')

plt.show()

# %%
X_test = df2['content']
y_test = df2['sentiment']

# %%
best_pred = model.predict(X_test)
print('Percentage correct: ', 100*np.sum(best_pred == y_test)/len(y_test))
# Out:
# Percentage correct:  41.73075758493308

# %%
titles_options = [("Confusion matrix", None)]
for title, normalize in titles_options:
    disp = plot_confusion_matrix(model, X_test, y_test,
                                 cmap=plt.cm.viridis,
                                 normalize=normalize)
    disp.ax_.set_title(title)

    print(title,'for test set')
    print(disp.confusion_matrix)
    print()

plt.show()
# Out:
# Confusion matrix for test set
# [[  13    0   52    2   43    0]
#  [   0    0    0    0    0    0]
#  [ 108   41 3948  133  866  113]
#  [  76   34 2695  328  637   72]
#  [ 303   69 2130   92 2536   35]
#  [  91   52 1344   45  589   66]]
